# %% [markdown]
# ## Sentimen Analisis Review Aplikasi Tokopedia

# %% [markdown]
# ### Import Library

# %%
from google_play_scraper import app, reviews, Sort, reviews_all
import pandas as pd  # Pandas untuk manipulasi dan analisis data

# %%
import nltk  # Import pustaka NLTK (Natural Language Toolkit).
nltk.download('punkt')  # Mengunduh dataset yang diperlukan untuk tokenisasi teks.
nltk.download('stopwords')  # Mengunduh dataset yang berisi daftar kata-kata berhenti (stop words) dalam berbagai bahasa.
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\sltna\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\sltna\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# True

# %% [markdown]
# ### Scraping

# %%
scrape_review= reviews_all(
  'com.tokopedia.tkpd',            # ID aplikasi
  lang='en',                  # defaults to ‘en’
  country='sg',               # defaults to ‘us’
  sort = Sort.MOST_RELEVANT,  # defaults to Sort.MOST_RELEVANT
  filter_score_with=None      # defaults to None (means all score)
)

# %%
df = pd.DataFrame(scrape_review)
df
# Out:
#                                     reviewId       userName  \
# 0       839aea6d-95e6-4195-b5ec-08f9ed0ebfa0  A Google user
# 1       ecc92be3-cbfc-4806-bba0-12ad6a1ee04d  A Google user
# 2       1d95bead-4df7-4115-b301-438e7b128844  A Google user
# 3       833848b8-52ae-484b-a54e-95d7b76ef44e  A Google user
# 4       79a492d5-6e6c-4c65-9e72-830be94477ac  A Google user
# ...                                      ...            ...
# 184495  24cfa119-2918-4184-9dda-d6c1ec3a3d59  A Google user
# 184496  fe07d5e9-243a-4c4f-8025-a7ce4ae7bfb6  A Google user
# 184497  dce0b4d8-bf71-47d3-bb48-c158053373f3  A Google user
# 184498  279b7092-8fd3-4aad-ab65-83a6861fb936  A Google user
# 184499  b80c66b6-985f-4150-ab88-0ce09e991f45  A Google user
#
#                                                 userImage  \
# 0       https://play-lh.googleusercontent.com/EGemoI2N...
# 1       https://play-lh.googleusercontent.com/EGemoI2N...
# 2       https://play-lh.googleusercontent.com/EGemoI2N...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 184500 entries, 0 to 184499
# Data columns (total 11 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   reviewId              184500 non-null  object
#  1   userName              184500 non-null  object
#  2   userImage             184500 non-null  object
#  3   content               184497 non-null  object
#  4   score                 184500 non-null  int64
#  5   thumbsUpCount         184500 non-null  int64
#  6   reviewCreatedVersion  181098 non-null  object
#  7   at                    184500 non-null  datetime64[ns]
#  8   replyContent          61559 non-null   object
#  9   repliedAt             61559 non-null   datetime64[ns]
#  10  appVersion            181098 non-null  object
# dtypes: datetime64[ns](2), int64(2), object(7)
# memory usage: 15.5+ MB

# %%
# menghapus baris yang memiliki nilai yang hilang (NaN) dari df
clean_df = df.dropna()
clean_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 60193 entries, 0 to 184486
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   reviewId              60193 non-null  object
#  1   userName              60193 non-null  object
#  2   userImage             60193 non-null  object
#  3   content               60193 non-null  object
#  4   score                 60193 non-null  int64
#  5   thumbsUpCount         60193 non-null  int64
#  6   reviewCreatedVersion  60193 non-null  object
#  7   at                    60193 non-null  datetime64[ns]
#  8   replyContent          60193 non-null  object
#  9   repliedAt             60193 non-null  datetime64[ns]
#  10  appVersion            60193 non-null  object
# dtypes: datetime64[ns](2), int64(2), object(7)
# memory usage: 5.5+ MB

# %%
clean_df.to_csv("tokopedia_review.csv", index=None, header=True)
